# %% [markdown]
# E-Commerce Data12

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import os

# %%
data = pd.read_csv("D:/Medium/E-Commerce Data/data.csv", encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# Invoice Number

# %%
data['No'] = data['InvoiceNo'].str[0]

# %%
data['No'].value_counts()
# Out:
# 5    532618
# C      9288
# A         3
# Name: No, dtype: int64

# %%
data[data['No'] == 'C'].head(10)
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 141   C536379         D                           Discount        -1
# 154   C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 239   C536391     21484        CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557   PLASTERS IN TIN VINTAGE PAISLEY        -12
# 241   C536391     22553             PLASTERS IN TIN SKULLS       -24
# 939   C536506     22960           JAM MAKING SET WITH JARS        -6
#
#          InvoiceDate  UnitPrice  CustomerID         Country No
# 141   12/1/2010 9:41      27.50     14527.0  United Kingdom  C
# 154   12/1/2010 9:49       4.65     15311.0  United Kingdom  C
# 235  12/1/2010 10:24       1.65     17548.0  United Kingdom  C
# 236  12/1/2010 10:24       0.29     17548.0  United Kingdom  C
# 237  12/1/2010 10:24       0.29     17548.0  United Kingdom  C
# 238  12/1/2010 10:24       0.29     17548.0  United Kingdom  C
# 239  12/1/2010 10:24       3.45     17548.0  United Kingdom  C
# 240  12/1/2010 10:24       1.65     17548.0  United Kingdom  C
# 241  12/1/2010 10:24       1.65     17548.0  United Kingdom  C
# 939  12/1/2010 12:38       4.25     17897.0  United Kingdom  C

# %%
data[data['No'] == 'C'].Quantity.describe()
# Out:
# count     9288.000000
# mean       -29.885228
# std       1145.786965
# min     -80995.000000
# 25%         -6.000000
# 50%         -2.000000
# 75%         -1.000000
# max         -1.000000
# Name: Quantity, dtype: float64

# %%
# Products with start with C are returned articles

# %%
data[data['No'] == 'A']
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1  8/12/2011 14:50
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country No
# 299982   11062.06         NaN  United Kingdom  A
# 299983  -11062.06         NaN  United Kingdom  A
# 299984  -11062.06         NaN  United Kingdom  A

# %%
# Bad Operation ?

# %% [markdown]
# Stock Code

# %%
data['Code'] = data['StockCode'].str[0]

# %%
data['Code'].value_counts()
# Out:
# 2    438444
# 8     62988
# 4     11464
# 1      7627
# 7      7223
# 3      5758
# 9      4656
# P      1260
# D       832
# 5       641
# M       571
# C       160
# 6       113
# S        63
# B        40
# g        34
# A        34
# m         1
# Name: Code, dtype: int64

# %%
# Understanding letters code

# %%
data[data['Code'] == 'P'].Description.value_counts()
# Out:
# POSTAGE                       1252
# PADS TO MATCH ALL CUSHIONS       4
# Name: Description, dtype: int64

# %%
# P : POSTAGE Products

# %%
data[data['Code'] == 'D'].Description.value_counts()
# Out:
# DOTCOM POSTAGE                  709
# Discount                         77
# GIRLS PARTY BAG                  13
# BOYS PARTY BAG                   11
# ebay                              5
# BOXED GLASS ASHTRAY               4
# SUNJAR LED NIGHT NIGHT LIGHT      2
# HAYNES CAMPER SHOULDER BAG        1
# OOH LA LA DOGS COLLAR             1
# CAMOUFLAGE DOG COLLAR             1
# Name: Description, dtype: int64

# %%
data[(data['Code'] == 'D') & (data['StockCode'] != 'D') & (data['StockCode'] != 'DOT')]
# Out:
#        InvoiceNo  StockCode                   Description  Quantity  \
# 21326     538071   DCGS0076  SUNJAR LED NIGHT NIGHT LIGHT         1
# 24906     538349   DCGS0003           BOXED GLASS ASHTRAY         1
# 36460     539451   DCGS0003           BOXED GLASS ASHTRAY         1
# 39313     539631   DCGS0076  SUNJAR LED NIGHT NIGHT LIGHT         2
# 40052     539718   DCGS0070         CAMOUFLAGE DOG COLLAR         1
# 74825     542529   DCGS0055                           NaN        -1
# 74838     542531   DCGS0072                           NaN        -1
# 74839     542532   DCGS0074                           NaN        -1
# 75053     542541   DCGS0069         OOH LA LA DOGS COLLAR         1
# 75295     542582   DCGS0057                           NaN        -6
# 76251     542622   DCGS0003           BOXED GLASS ASHTRAY         1
# 84016     543358   DCGSSBOY                BOYS PARTY BAG         1
# 84017     543358  DCGSSGIRL               GIRLS PARTY BAG         3
# 97246     544599   DCGSSBOY                BOYS PARTY BAG         1
# 112723    545897   DCGSSBOY                BOYS PARTY BAG         5
# 112724    545897  DCGSSGIRL               GIRLS PARTY BAG         5
# 116891    546306   DCGSSBOY                BOYS PARTY BAG         1
# 116892    546306  DCGSSGIRL               GIRLS PARTY BAG         2
# 128107    547249   DCGSSBOY                BOYS PARTY BAG         6
# 128108    547249  DCGSSGIRL               GIRLS PARTY BAG        17
# 128269    547250  DCGSSGIRL               GIRLS PARTY BAG         2
# 150864    549524  DCGSSGIRL               GIRLS PARTY BAG         1
# 160487    550458   DCGSSBOY                BOYS PARTY BAG         1
# 170783    551340   DCGS0004    HAYNES CAMPER SHOULDER BAG         1
# 176006    551995   DCGS0003           BOXED GLASS ASHTRAY         1
# 176169    551997  DCGSSGIRL               GIRLS PARTY BAG         2
# 178669    552234   DCGSSBOY                BOYS PARTY BAG         7
# 178670    552234  DCGSSGIRL               GIRLS PARTY BAG         2
# 262771    559923   DCGSSBOY                BOYS PARTY BAG        20
# 278378    561209   DCGSSBOY                BOYS PARTY BAG         2
# 278379    561209  DCGSSGIRL               GIRLS PARTY BAG         5
# 279251    561249   DCGS0073                          ebay        -4
# 279252    561250   DCGS0071                           NaN        -2
# 279253    561251   DCGS0070                           NaN        -8
# 279254    561252   DCGS0069                          ebay        -5
# 279255    561253   DCGS0068                          ebay       -10
# 279256    561254   DCGS0067                          ebay       -11
# 279257    561255  DCGS0066P                           NaN        -3
# 279258    561256   DCGS0003                          ebay        -7
# 297098    562933  DCGSSGIRL               GIRLS PARTY BAG         5
# 318312    564825  DCGSSGIRL               GIRLS PARTY BAG         1
# 365966    568716   DCGSSBOY                BOYS PARTY BAG         2
# 408203    571931  DCGSSGIRL               GIRLS PARTY BAG         1
# 474602    576840  DCGSSGIRL               GIRLS PARTY BAG         1
# 518711    580115   DCGSSBOY                BOYS PARTY BAG         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country No Code
# 21326    12/9/2010 14:09      16.13         NaN  United Kingdom  5    D
# 24906   12/10/2010 14:59       2.51         NaN  United Kingdom  5    D
# 36460   12/17/2010 16:59       2.51         NaN  United Kingdom  5    D
# 39313   12/20/2010 15:03      16.13         NaN  United Kingdom  5    D
# 40052   12/21/2010 13:06      12.72         NaN  United Kingdom  5    D
# 74825    1/28/2011 13:08       0.00         NaN  United Kingdom  5    D
# 74838    1/28/2011 13:08       0.00         NaN  United Kingdom  5    D
# 74839    1/28/2011 13:09       0.00         NaN  United Kingdom  5    D
# 75053    1/28/2011 14:25      15.79         NaN  United Kingdom  5    D
# 75295    1/28/2011 15:01       0.00         NaN  United Kingdom  5    D
# 76251     1/31/2011 9:09       2.46         NaN  United Kingdom  5    D
# 84016     2/7/2011 14:04       3.29         NaN  United Kingdom  5    D
# 84017     2/7/2011 14:04       3.29         NaN  United Kingdom  5    D
# 97246    2/21/2011 18:15       3.29         NaN  United Kingdom  5    D
# 112723    3/7/2011 17:22       3.29         NaN  United Kingdom  5    D
# 112724    3/7/2011 17:22       3.29         NaN  United Kingdom  5    D
# 116891   3/10/2011 16:16       3.29         NaN  United Kingdom  5    D
# 116892   3/10/2011 16:16       3.29         NaN  United Kingdom  5    D
# 128107    3/22/2011 9:27       3.29         NaN  United Kingdom  5    D
# 128108    3/22/2011 9:27       3.29         NaN  United Kingdom  5    D
# 128269    3/22/2011 9:30       3.29         NaN  United Kingdom  5    D
# 150864    4/8/2011 15:42       3.29         NaN  United Kingdom  5    D
# 160487   4/18/2011 13:13       3.29         NaN  United Kingdom  5    D
# 170783   4/27/2011 17:23      16.63         NaN  United Kingdom  5    D
# 176006    5/5/2011 15:42       2.46         NaN  United Kingdom  5    D
# 176169    5/5/2011 15:47       3.29         NaN  United Kingdom  5    D
# 178669    5/6/2011 16:01       3.29         NaN  United Kingdom  5    D
# 178670    5/6/2011 16:01       3.29         NaN  United Kingdom  5    D
# 262771   7/13/2011 16:07       3.29         NaN  United Kingdom  5    D
# 278378   7/25/2011 16:57       1.25         NaN  United Kingdom  5    D
# 278379   7/25/2011 16:57       1.25         NaN  United Kingdom  5    D
# 279251   7/26/2011 11:51       0.00         NaN  United Kingdom  5    D
# 279252   7/26/2011 11:51       0.00         NaN  United Kingdom  5    D
# 279253   7/26/2011 11:51       0.00         NaN  United Kingdom  5    D
# 279254   7/26/2011 11:52       0.00         NaN  United Kingdom  5    D
# 279255   7/26/2011 11:52       0.00         NaN  United Kingdom  5    D
# 279256   7/26/2011 11:52       0.00         NaN  United Kingdom  5    D
# 279257   7/26/2011 11:52       0.00         NaN  United Kingdom  5    D
# 279258   7/26/2011 11:53       0.00         NaN  United Kingdom  5    D
# 297098   8/10/2011 16:51       3.29         NaN  United Kingdom  5    D
# 318312   8/30/2011 12:26       3.29         NaN  United Kingdom  5    D
# 365966   9/28/2011 16:13       3.29         NaN  United Kingdom  5    D
# 408203  10/19/2011 16:59       3.29         NaN  United Kingdom  5    D
# 474602  11/16/2011 15:23       3.29         NaN  United Kingdom  5    D
# 518711   12/1/2011 16:22       3.29         NaN  United Kingdom  5    D

# %%
# DCGS = Discount

# %%
data[data['Code'] == 'C'].Description.value_counts()
# Out:
# CARRIAGE           143
# CRUK Commission     16
# Name: Description, dtype: int64

# %%
data[data['Code'] == 'C'].Country.value_counts()
# Out:
# EIRE               108
# United Kingdom      47
# Channel Islands      3
# France               2
# Name: Country, dtype: int64

# %%
data[data['Code'] == 'M'].Description.value_counts()
# Out:
# Manual    571
# Name: Description, dtype: int64

# %%
data[data['Code'] == 'B'].Description.value_counts()
# Out:
# Bank Charges       37
# Adjust bad debt     3
# Name: Description, dtype: int64

# %%
data[data['Code'] == 'S'].Description.value_counts()
# Out:
# SAMPLES    63
# Name: Description, dtype: int64

# %%
data[data['Code'] == 'A'].Description.value_counts()
# Out:
# AMAZON FEE    34
# Name: Description, dtype: int64

# %%
data[data['Code'] == 'g'].Description.value_counts()
# Out:
# Dotcomgiftshop Gift Voucher £20.00     9
# Dotcomgiftshop Gift Voucher £10.00     8
# Dotcomgiftshop Gift Voucher £30.00     7
# Dotcomgiftshop Gift Voucher £50.00     4
# Dotcomgiftshop Gift Voucher £40.00     3
# to push order througha s stock was     1
# Name: Description, dtype: int64

# %%
# G = Gift

# %%
data[data['Code'] == 'm'].Description.value_counts()
# Out:
# Manual    1
# Name: Description, dtype: int64

# %%
# Change this stock code
data.loc[data.Code == 'm', 'Code'] = 'M'

# %% [markdown]
# Unit Price

# %%
data.UnitPrice.describe()
# Out:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
# Understanding negative values
data[data.UnitPrice < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country No Code
# 299983  -11062.06         NaN  United Kingdom  A    B
# 299984  -11062.06         NaN  United Kingdom  A    B

# %%
data[data.UnitPrice >= 0].UnitPrice.describe()
# Out:
# count    541907.000000
# mean          4.651957
# std          94.395447
# min           0.000000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
# Some articles are free (Unit Price = 0)

# %%
# Distribution of prices < 10
plt.figure(figsize=(10,6))
sns.distplot(data[(data.UnitPrice < 10) & (data.UnitPrice >= 0)].UnitPrice, hist = False)
# Out:
# C:\Users\ubjd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='UnitPrice', ylabel='Density'>

# %% [markdown]
# Quantity

# %%
data.Quantity.describe()
# Out:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
# Distribution of quantity
plt.figure(figsize=(10,6))
sns.distplot(data[data.Quantity > 0].Quantity, hist = False)
# Out:
# C:\Users\ubjd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quantity', ylabel='Density'>

# %% [markdown]
# Countries

# %%
data.Country.value_counts()[:10]
# Out:
# United Kingdom    495478
# Germany             9495
# France              8557
# EIRE                8196
# Spain               2533
# Netherlands         2371
# Belgium             2069
# Switzerland         2002
# Portugal            1519
# Australia           1259
# Name: Country, dtype: int64

# %% [markdown]
# Total Price

# %%
# Negative quantities as positive
data['Quantity'] = abs(data['Quantity'])

# %%
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# %%
# Distribution of quantity
plt.figure(figsize=(10,6))
sns.distplot(data[data.TotalPrice > 0].TotalPrice, hist = False)
# Out:
# C:\Users\ubjd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TotalPrice', ylabel='Density'>

# %% [markdown]
# Invoice Date

# %%
data['Date'] = pd.to_datetime(data['InvoiceDate'])

# %%
data['Date'].head(10)
# Out:
# 0   2010-12-01 08:26:00
# 1   2010-12-01 08:26:00
# 2   2010-12-01 08:26:00
# 3   2010-12-01 08:26:00
# 4   2010-12-01 08:26:00
# 5   2010-12-01 08:26:00
# 6   2010-12-01 08:26:00
# 7   2010-12-01 08:28:00
# 8   2010-12-01 08:28:00
# 9   2010-12-01 08:34:00
# Name: Date, dtype: datetime64[ns]

# %%
data['year'] = data['Date'].dt.year
data['month'] = data['Date'].dt.month
data['day'] = data['Date'].dt.day
data['hour'] = data['Date'].dt.hour

# %%
data.year.value_counts()
# Out:
# 2011    499428
# 2010     42481
# Name: year, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data.month)
# Out:
# C:\Users\ubjd\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
# Majority in November and December (for Christmas)

# %%
plt.figure(figsize=(10,6))
sns.countplot(data.day)
# Out:
# C:\Users\ubjd\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(data.hour)
# Out:
# C:\Users\ubjd\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %% [markdown]
# Data Featuring

# %%
# check missing values for each column 
data.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# No                  0
# Code                0
# TotalPrice          0
# Date                0
# year                0
# month               0
# day                 0
# hour                0
# dtype: int64

# %% [markdown]
# Products Classification

# %%
prod = data[~data.Description.isnull()]

# %%
prod['Description'].head(10)
# Out:
# 0     WHITE HANGING HEART T-LIGHT HOLDER
# 1                    WHITE METAL LANTERN
# 2         CREAM CUPID HEARTS COAT HANGER
# 3    KNITTED UNION FLAG HOT WATER BOTTLE
# 4         RED WOOLLY HOTTIE WHITE HEART.
# 5           SET 7 BABUSHKA NESTING BOXES
# 6      GLASS STAR FROSTED T-LIGHT HOLDER
# 7                 HAND WARMER UNION JACK
# 8              HAND WARMER RED POLKA DOT
# 9          ASSORTED COLOUR BIRD ORNAMENT
# Name: Description, dtype: object

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(max_words=1000,margin=0).generate(' '.join(prod['Description']))
plt.figure(figsize = (15, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# fill description with nan

prod['text'] = prod['Description'].fillna('')
# Out:
# <ipython-input-52-b21f1e738698>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['text'] = prod['Description'].fillna('')

# %%
# lower description

prod['text'] = prod['text'].str.lower()
# Out:
# <ipython-input-53-15b12f83feff>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['text'] = prod['text'].str.lower()

# %%
# stopwords

from nltk.corpus import stopwords
stop = stopwords.words('english')

prod['text'] = prod['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# <ipython-input-54-e7681f556934>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['text'] = prod['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(max_words=1000,margin=0).generate(' '.join(prod['text']))
plt.figure(figsize = (15, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(prod['text'])

# %%
# Calculate sum of squared distances
ssd = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(X)
    ssd.append(km.inertia_)

# %%
# Plot sum of squared distances / elbow method
plt.figure(figsize=(10,6))
plt.plot(K, ssd, 'bx-')
plt.xlabel('k')
plt.ylabel('ssd')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# Best number of clusters is 5

# %%
# Create and fit model
kmeans = KMeans(n_clusters=5)
model = kmeans.fit(X)

# %%
pred = model.labels_
prod['Cluster_prod'] = pred
# Out:
# <ipython-input-61-172c855b5455>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod['Cluster_prod'] = pred

# %%
prod = prod[['Description', 'text', 'Cluster_prod']]

# %%
prod.head()
# Out:
#                            Description                                 text  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER   white hanging heart t-light holder
# 1                  WHITE METAL LANTERN                  white metal lantern
# 2       CREAM CUPID HEARTS COAT HANGER       cream cupid hearts coat hanger
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  knitted union flag hot water bottle
# 4       RED WOOLLY HOTTIE WHITE HEART.       red woolly hottie white heart.
#
#    Cluster_prod
# 0             0
# 1             0
# 2             0
# 3             2
# 4             0

# %%
fig = plt.figure(figsize = (20, 15))
for c in range(len(prod['Cluster_prod'].unique())):
    ax = fig.add_subplot(3,2,c+1)
    ax.set_title('Cluster %d'%c)
    cluster = prod[prod.Cluster_prod == c]
    wordcloud = WordCloud( max_words=1000,margin=0).generate(' '.join(cluster['text']))
    ax.imshow(wordcloud)
    ax.axis("off")

# %%
# Cluster A : Bags
# Cluster B : Signs
# Cluster C : Kitchen
# Cluster D : Decoration
# Cluster E : Retrospots

# %% [markdown]
# Customers Classification

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'No', 'Code', 'TotalPrice',
#        'Date', 'year', 'month', 'day', 'hour'],
#       dtype='object')

# %%
cus = data[['CustomerID', 'InvoiceDate', 'Quantity', 'UnitPrice', 'Country', 'TotalPrice']]

# %%
cus = cus[~cus.CustomerID.isnull()]

# %% [markdown]
# Total products bought

# %%
cus_prod = cus.groupby('CustomerID')['Quantity'].sum().reset_index()
cus_prod.columns = ['CustomerID', 'TotalProducts']

# %%
cus = cus.merge(cus_prod, on='CustomerID')

# %% [markdown]
# Number of transactions (1 per day)

# %%
cus['InvoiceDate'] = cus['InvoiceDate'].str.split(' ').str[0]

# %%
transactions = cus[['CustomerID', 'InvoiceDate']].drop_duplicates()

# %%
transactions = transactions.groupby('CustomerID')['InvoiceDate'].count().reset_index()
transactions.columns = ['CustomerID', 'Transactions']

# %%
cus = cus.merge(transactions, on='CustomerID')

# %%
cus = cus.drop(['Quantity', 'UnitPrice', 'InvoiceDate'], axis=1)

# %%
# drop duplicates
cus = cus.drop_duplicates()

# %%
len(cus)
# Out:
# 146536

# %%
cus.head()
# Out:
#    CustomerID         Country  TotalPrice  TotalProducts  Transactions
# 0     17850.0  United Kingdom       15.30           1773             3
# 1     17850.0  United Kingdom       20.34           1773             3
# 2     17850.0  United Kingdom       22.00           1773             3
# 5     17850.0  United Kingdom       15.30           1773             3
# 6     17850.0  United Kingdom       25.50           1773             3

# %%
# Label encoder
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
cus['Country'] = le.fit_transform(cus.Country.values)

# %%
# cus['No'] = le.fit_transform(cus.No.values)
# cus['Code'] = le.fit_transform(cus.Code.values)

# %%
# Calculate sum of squared distances
ssd = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(cus)
    ssd.append(km.inertia_)

# %%
# Plot sum of squared distances / elbow method
plt.figure(figsize=(10,6))
plt.plot(K, ssd, 'bx-')
plt.xlabel('k')
plt.ylabel('ssd')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# Best number of clusters is 3

# %%
# Create and fit model
kmeans = KMeans(n_clusters=3)
model = kmeans.fit(cus)

# %%
pred = model.labels_
cus['Cluster_cus'] = pred

# %%
cus.head()
# Out:
#    CustomerID  Country  TotalPrice  TotalProducts  Transactions  Cluster_cus
# 0     17850.0       35       15.30           1773             3            0
# 1     17850.0       35       20.34           1773             3            0
# 2     17850.0       35       22.00           1773             3            0
# 5     17850.0       35       15.30           1773             3            0
# 6     17850.0       35       25.50           1773             3            0

# %%
# Create PCA for data visualization / Dimensionality reduction to 2D graph
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_model = pca.fit_transform(cus)
cus_transform = pd.DataFrame(data = pca_model, columns = ['PCA1', 'PCA2'])
cus_transform['Cluster_cus'] = pred

# %%
plt.figure(figsize=(10,10))
g = sns.scatterplot(data=cus_transform, x='PCA1', y='PCA2', palette=sns.color_palette()[:3], hue='Cluster_cus')
title = plt.title('Personality Clusters with PCA')

# %%
customers = cus.groupby('Cluster_cus').mean()
customers = customers.reset_index()

# %%
customers.columns
# Out:
# Index(['Cluster_cus', 'CustomerID', 'Country', 'TotalPrice', 'TotalProducts',
#        'Transactions'],
#       dtype='object')

# %%
customers[['Cluster_cus', 'CustomerID', 'Country', 'TotalPrice', 'TotalProducts', 'Transactions']]
# Out:
#    Cluster_cus    CustomerID    Country  TotalPrice  TotalProducts  \
# 0            0  15308.583280  33.248592   23.995984    1938.435342
# 1            1  14654.051948  23.124675  815.203818  197850.932468
# 2            2  15263.112738  26.655930  219.295411   58168.037775
#
#    Transactions
# 0      7.984664
# 1     46.529870
# 2     55.834261

# %%
# Cluster A : From UK : few transactions and products, small total price
# Cluster B : Regular with a good amount of products (weekly shopping)
# Cluster C : Big amount of products, maybe for stock

# %% [markdown]
# Let's look at the products for these clusters

# %%
prod_cust = data.merge(cus[['Cluster_cus', 'CustomerID']], on='CustomerID')

# %%
prod_cust = prod_cust.drop_duplicates()

# %%
prod_cust['text'] = prod_cust['Description'].fillna('')
prod_cust['text'] = prod_cust['text'].str.lower()
prod_cust['text'] = prod_cust['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
fig = plt.figure(figsize = (20, 15))
for c in range(len(prod_cust['Cluster_cus'].unique())):
    ax = fig.add_subplot(3,1,c+1)
    ax.set_title('Cluster %d'%c)
    cluster = prod_cust[prod_cust.Cluster_cus == c]
    wordcloud = WordCloud(max_words=1000,margin=0).generate(' '.join(cluster['text']))
    ax.imshow(wordcloud)
    ax.axis("off")
